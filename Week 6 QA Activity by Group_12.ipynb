# %% [markdown]
# # Week 6 QA Activity

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r'C:\assignment\Dataset_w6.xlsx')

# %%
data.head()
# Out:
#                country          Region  Surface area (km2)  \
# 0          Afghanistan    SouthernAsia            652864.0
# 1              Albania  SouthernEurope             28748.0
# 2              Algeria  NorthernAfrica           2381741.0
# 3               Angola    MiddleAfrica           1246700.0
# 4  Antigua and Barbuda       Caribbean               442.0
#
#    Population in thousands (2017)  GDP per capita (current US$)  \
# 0                         35530.0                         623.2
# 1                          2930.0                        3984.2
# 2                         41318.0                        4154.1
# 3                         29784.0                        4714.1
# 4                           102.0                       14764.5
#
#    Agricultural production index   International trade: Imports (million US$)
# 0                           125.0                                      3568.0
# ...

# %% [markdown]
# # 1. Find out how many countries are there in the dataset.

# %%
data['country'].nunique()
# Out:
# 196

# %% [markdown]
# # 2.Examine the data by using visualizations.

# %%
sns.stripplot(x='Region',y='Population in thousands (2017)', data=data)
plt.xticks(rotation=90);

# %%
sns.violinplot(x='Region',y='International trade: Imports (million US$)', data=data)
plt.xticks(rotation=90);

# %%
sns.barplot(x='Region',y='GDP per capita (current US$)', data=data)
plt.xticks(rotation=90);

# %% [markdown]
# # 3.Find out how many countries with respect to the region are available in the dataset

# %%
data.groupby('Region')['country'].nunique()
# Out:
# Region
# Caribbean            16
# CentralAmerica        8
# CentralAsia           5
# EasternAfrica        17
# EasternAsia           7
# EasternEurope        10
# Melanesia             5
# Micronesia            4
# MiddleAfrica          9
# NorthernAfrica        5
# NorthernAmerica       4
# NorthernEurope       10
# Oceania               2
# Polynesia             5
# South-easternAsia    11
# SouthAmerica         12
# SouthernAfrica        5
# SouthernAsia          9
# SouthernEurope       12
# WesternAfrica        15
# WesternAsia          18
# WesternEurope         7
# Name: country, dtype: int64

# %% [markdown]
# # 4.On average which region has the highest

# %% [markdown]
# # 4.1 GDP per capita (current US$)

# %%
GDP=data.groupby('Region')['GDP per capita (current US$)'].mean()
GDP.nlargest(1)
# Out:
# Region
# NorthernAmerica    57659.0
# Name: GDP per capita (current US$), dtype: float64

# %% [markdown]
# # 4.2)International trade: Imports (million US$)

# %%
IT = data.groupby('Region')['International trade: Imports (million US$)'].mean()
IT.nlargest(1)
# Out:
# Region
# NorthernAmerica    663552.25
# Name: International trade: Imports (million US$), dtype: float64

# %% [markdown]
# # 5.Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
region_GDP =data.groupby('Region')['GDP per capita (current US$)'].std()
region_GDP.nsmallest(1)
# Out:
# Region
# WesternAfrica    815.095399
# Name: GDP per capita (current US$), dtype: float64
